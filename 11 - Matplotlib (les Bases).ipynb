# %% [markdown]
# # Matplotlib : Graphiques de Base

# %% [markdown]
# ## 1. Pyplot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Graphiques simples

# %%
X = np.linspace(0, 2, 10)
y = X**2

plt.plot(X, y)
plt.show()

# %%
plt.scatter(X, y)
plt.show()

# %% [markdown]
# ### Styles Graphiques
# Il existe beaucoup de styles a ajouter aux graphiques. Voici les plus importants a retenir :
# - **c** : couleur de la ligne
# - **lw** : epaisseur de la ligne (pour les graphiques plot)
# - **ls** : style de la ligne (pour les graphiques plot)
# - **size** : taille du point (pour les graphiques scatter)
# - **marker** : style de points (pour les graphiques scatter)
# - **alpha** : transparence du graphique

# %%
plt.plot(X, y, c='red', lw=4, ls='--', alpha=0.8)
plt.show()

# %% [markdown]
# ## 2. Cycle de vie d'une figure
# Pour créer des figures proprements, on doit suivre le cycle de vie suivant :
# 1. **plt.figure**(figsize())
# 2. **plt.plot()**
# 3. Extras (titre, axes, legendes)
# 4. **plt.show()**

# %%
X = np.linspace(0, 2, 10)

plt.figure() # Création d'une figure
plt.plot(X, X**2, label='quadratique') # premiere courbe
plt.plot(X, X**3, label='cubique') # deuxieme courbe
# Extra information
plt.title('figure 1') # titre
plt.xlabel('axe x') # axes
plt.ylabel('axe y') # axes
plt.legend() # legend

plt.savefig('figure.png') # sauvegarde la figure dans le repertoire de travail
plt.show() # affiche la figure

# %% [markdown]
# ## 3. Subplots
# Les subplots sont un autre éléments a ajouter pour créer plusieurs graphiques sur une meme figure

# %%
plt.subplot(2, 1, 1)
plt.plot(X, y, c='red')
plt.subplot(2, 1, 2)
plt.plot(X, y, c='blue')

# %% [markdown]
# ## 4. Méthode orientée objet

# %%
fig, ax = plt.subplots(2, 1, sharex=True) # partage le meme axe pour les subplots
ax[0].plot(X, y)
ax[1].plot(X, np.sin(X))
plt.show()

# %% [markdown]
# ## 5. Exercice et Solution
# Créez une fonction "graphique" qui permet de tracer sur une seule et meme figure une série de graphiques issue d'un dictionnaire contenant plusieurs datasets :

# %%
def graphique(dataset):
  # Votre code ici...
  return

# Voici le dataset utilisé
dataset = {f"experience{i}": np.random.randn(100) for i in range(4)}

dataset
# Out:
# {'experience0': array([ 0.41239406, -2.05170468, -0.02884759,  0.40831832, -1.73639998,
#          1.37846163,  1.0723132 , -0.97606381, -1.31119523,  0.256941  ,
#         -0.36379997, -0.99900982, -0.41804386, -0.42878755, -0.18624841,
#         -0.53654568, -0.66449703, -1.02618434,  0.59530223, -0.05333831,
#          1.34102206,  1.60998169,  0.02222284,  0.4209041 , -0.37957137,
#         -1.7852646 ,  0.65324256,  0.51221499, -0.10854411,  1.57639958,
#         -0.55269279,  0.84817109, -0.22009973,  0.30215047, -0.0486421 ,
#         -1.29746405, -1.79671033,  1.08752334, -0.91017107,  1.23806663,
#         -0.42958408,  2.92388687,  0.07466548, -0.64960756, -1.47927104,
#          1.56728636,  2.09243386,  0.61840683,  1.16117619,  0.11543235,
#          0.29363335, -0.72211455, -0.43675043,  1.27490452, -0.14489065,
#         -0.00885028,  0.0074508 , -0.24032837, -0.82039133, -0.44426177,
#          1.94559054,  0.48924229, -0.09668805,  0.98639946,  0.46628611,
#         -0.1777157 ,  0.99028885,  1.17530527, -0.96125916, -0.35453931,
#          0.33671386, -1.12939123,  0.72938334,  0.63107696,  1.64761147,
#         -0.72296598,  0.36861076,  0.41391636,  0.00806397, -0.0136259 ,
#          0.56146569, -1.17106154,  0.36775895, -0.60606331, -0.99837021,
#         -0.87688585,  0.50130941,  0.95949618,  0.91933611, -0.73801743,
#          0.56886549,  0.76078267, -1.20910769, -0.94071408,  0.67109145,
#         -0.38283332, -1.05087571, -0.96435701, -1.31405022, -0.98385506,
#         -0.10281174,  0.83778805, -0.07752978, -0.65050531,  0.32545764,
#          1.35464947, -0.58858991,  1.14611777,  0.70251753, -1.29135419,
#         -0.3971752 , -1.27273829,  0.6675618 , -1.57118055,  0.22808255]),
#  'experience3': array([-0.60967957, -0.34264511, -0.11049728,  1.45591691, -0.19806314,
#         -1.01271699, -0.87772849,  0.21961128,  0.39054681,  0.36453214,
#          0.80994526,  1.25935909, -0.66657874,  0.04998596, -1.305489  ,
#         -1.21210497, -0.77046985,  0.34196718, -0.05070935,  0.25945249,
#          1.08486112,  0.81046864,  0.66822992, -0.12917688, -1.14038441,
#         -2.21031655, -0.53523152, -1.17643631,  0.14945988,  0.44831987,
#         -0.36127277, -1.48996342,  1.09166571,  0.30720077,  0.45669716,
#          1.55275602,  0.32214333, -0.69213686,  1.45868606,  0.65284   ,
#          0.42353619,  0.7743787 ,  1.14839015, -0.11360215,  0.34125394,
#         -1.42930701, -0.31759969,  0.0278272 ,  1.54929116,  1.27425941,
#          1.67759381,  0.72894308,  0.58194797,  0.38053356, -0.30791208,
#         -0.70653851, -2.41166846,  0.25792409, -0.91169102, -0.44991497,
#         -0.58777068, -1.6017441 , -0.99265267,  0.15261345,  0.13091784,
#         -0.98474299, -0.68402874, -2.44599646,  1.75481117,  0.21566242,
#          0.14229374,  0.43007054,  1.53679986,  1.55423527,  0.40040759,
#          0.94415463, -0.50466365,  0.60299929,  1.36356508,  0.96114134,
#         -0.43527308,  0.89070395,  0.18621113,  0.83011479, -0.21792722,
#         -0.76592498, -1.69989592, -0.34358977, -0.36738708,  1.71610559,
#          0.66784842, -1.2988685 ,  0.65036911,  0.94733718,  0.62900857,
#          2.2050237 , -0.06705896, -1.16457881,  0.76817505, -1.47993041])}

# %%
# SOLUTION
def graphique(data):
    n = len(data)
    plt.figure(figsize=(12, 20))
    
    for k, i in zip(data.keys(), range(1, n+1)):
        plt.subplot(n, 1, i)
        plt.plot(data[k])
        plt.title(k)
        
    plt.show()

# %%
graphique(dataset)
